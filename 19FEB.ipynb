# %% [markdown]
# ASSIGNMENT: 18

# %% [markdown]
# 1.What is Flask Framework? What are the advantages of Flask Framework?

# %% [markdown]
# Flask is a lightweight, open-source web framework for Python that is designed to create web applications quickly and easily. Flask was created by Armin Ronacher in 2010 and has since become one of the most popular web frameworks in Python.
#
# Some advantages of Flask include:
#
# Lightweight and Flexible: Flask is a micro-framework, which means it has a small core and is highly customizable. This makes it easy to use for small projects and allows developers to add only the components they need.
#
# Easy to Learn: Flask is easy to learn and has a simple syntax that is easy to understand. It also has a large community of developers who are willing to help beginners.
#
# Built-in Development Server: Flask comes with a built-in development server, which makes it easy to test and debug applications.
#
# Jinja2 Templating: Flask uses Jinja2 as its template engine, which provides an easy way to create dynamic HTML pages.
#
# Large Community: Flask has a large and active community of developers who contribute to its development and provide support to other developers.
#
# Extensibility: Flask can be easily extended with third-party libraries and plugins, which can add functionality to an application without requiring developers to write the code themselves.

# %% [markdown]
# 2. Create a simple Flask application to display ‘Hello World!!’.

# %% [markdown]
# ![Annotation 2023-03-20 202627.png](attachment:a2110e66-0216-4ac3-9be6-d7225dec223f.png)

# %% [markdown]
# 3.  What is App routing in Flask? Why do we use app routes?

# %% [markdown]
# App Routing means mapping the URLs to a specific function that will handle the logic for that URL. Modern web frameworks use more meaningful URLs to help users remember the URLs and make navigation simpler.
#
# App routing is used to map the specific URL with the associated function that is intended to perform some task. It is used to access some particular page like Flask Tutorial in the web application.
#
# In our first application, the URL ('/') is associated with the home function that returns a particular string displayed on the web page.
#
# In other words, we can say that if we visit the particular URL mapped to some particular function, the output of that function is rendered on the browser's screen.

# %% [markdown]
# 4. Create a “/welcome” route to display the welcome message “Welcome to ABC Corporation” and a “/”
# route to show the following details:
#
#     Company Name: ABC Corporation
#
#     Location: India
#
#     Contact Detail: 999-999-9999

# %% [markdown]
# ![image.png](attachment:9cf35421-a3a3-483b-81a2-48cfdeee2b70.png)

# %% [markdown]
# ![image.png](attachment:473ef52d-3152-40ac-8d7b-3916a1b0d8e9.png)

# %% [markdown]
# ![image.png](attachment:6e74a351-dc55-4d6b-9e8f-61da79dfb7bd.png)

# %% [markdown]
# 5. What function is used in Flask for URL Building? Write a Python code to demonstrate the working of the
# url_for() function

# %% [markdown]
# The url_for() function is used in Flask for URL building. It generates a URL to a specific function based on its name and arguments. This is useful for creating links that are independent of the URL scheme and hostname.

# %%
'''
from flask import Flask, url_for

app = Flask(__name__)

@app.route('/')
def index():
    return 'Hello, World!'

@app.route('/user/<username>')
def profile(username):
    return f'Hello, {username}!'

with app.test_request_context():
    print(url_for('index'))      # Output: /
    print(url_for('profile', username='john'))  # Output: /user/john
    '''
# Out:
# "\nfrom flask import Flask, url_for\n\napp = Flask(__name__)\n\n@app.route('/')\ndef index():\n    return 'Hello, World!'\n\n@app.route('/user/<username>')\ndef profile(username):\n    return f'Hello, {username}!'\n\nwith app.test_request_context():\n    print(url_for('index'))      # Output: /\n    print(url_for('profile', username='john'))  # Output: /user/john\n    "
